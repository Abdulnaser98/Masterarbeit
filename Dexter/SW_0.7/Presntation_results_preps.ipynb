# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt  # Import plt module from matplotlib

# %%
All Features:
C-0
overall_comparisons = #21170
tests = ['ks','wasserstein_dist','PSI-Test','MMD']
number_of_similar_files = [49,126,146,69]
number_of_similar_datasets = [124,584,9816,342]
dataset_size_mean = [2595,2595,2595]
dataset_size_median = [351,351,351]


C-100
overall_comparisons = #21170
tests = ['ks','wasserstein_dist','PSI-Test','MMD']
number_of_similar_files = [89,127,146,'unkown']
number_of_similar_datasets = [958,740,11920,'Unknown']
dataset_size_mean = [618,618,618]
dataset_size_median = [121,121,121]

# %% [markdown]
# # Distribution Test

# %% [markdown]
# ## All Dirty

# %%
# Overall number of comparison is 10585
tests = ['ks','wasserstein_dist','PSI-Test','MMD','ks','wasserstein_dist','PSI-Test']
test_type = ['All_Features','All_Features','All_Features','All_Features','Majority_of_features','Majority_of_features','Majority_of_features']
number_of_record_linkage_tasks_with_at_least_one_similar = [83,138,143,69,135,143,145]
number_of_similar_record_likage_comparsions = [235,1699,4908,342,1300,4482,8686]
dataset_size_mean = [1306,1306,1306,1306,1306,1306,1306]
dataset_size_median = [21,21,21,21,21,21,21]


# Create a dictionary with your lists
data = {
    'tests': tests,
    'test_type':test_type,
    'number_of_record_linkage_tasks_with_at_least_one_similar': number_of_record_linkage_tasks_with_at_least_one_similar,
    'number_of_similar_record_likage_comparsions': number_of_similar_record_likage_comparsions,
    'dataset_size_mean': dataset_size_mean,
    'dataset_size_median': dataset_size_median
}


df = pd.DataFrame(data)

df['number_of_similar_record_likage_comparsions'] = df['number_of_similar_record_likage_comparsions'] / 10585

plt.figure(figsize=(20, 6)) 
sns.barplot(x='test_type', y='number_of_record_linkage_tasks_with_at_least_one_similar', hue='tests', data=df)
plt.title('Number of not singlton record linkage tasks per statistical test')
plt.xlabel('Test Type')
plt.ylabel('Number of not singlton record linkage tasks')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
plt.legend(title='Tests',fontsize='large',loc='upper right')  # Add legend title
plt.show()


## Ich muss noch die Threshold für wasserstein test ändern

# %% [markdown]
# ## All clean

# %%
# Overall number of comparison is 10585
tests = ['ks','wasserstein_dist','PSI-Test','MMD','ks','wasserstein_dist','PSI-Test']
test_type = ['All_Features','All_Features','All_Features','All_Features','Majority_of_features','Majority_of_features','Majority_of_features']
number_of_record_linkage_tasks_with_at_least_one_similar = [129,140,144,98,145,145,145]
number_of_similar_record_likage_comparsions = [1843,2176,5960,1822,5057,6098,9692]
dataset_size_mean = [317,317,317,317,317,317,317]
dataset_size_median = [17,17,17,17,17,17,17]


# Create a dictionary with your lists
data = {
    'tests': tests,
    'test_type':test_type,
    'number_of_record_linkage_tasks_with_at_least_one_similar': number_of_record_linkage_tasks_with_at_least_one_similar,
    'number_of_similar_record_likage_comparsions': number_of_similar_record_likage_comparsions,
    'dataset_size_mean': dataset_size_mean,
    'dataset_size_median': dataset_size_median
}


df = pd.DataFrame(data)

df['number_of_similar_record_likage_comparsions'] = df['number_of_similar_record_likage_comparsions'] / 10585

plt.figure(figsize=(20, 6)) 
sns.barplot(x='test_type', y='number_of_record_linkage_tasks_with_at_least_one_similar', hue='tests', data=df)
plt.title('Number of not singlton record linkage tasks per statistical test')
plt.xlabel('Test Type')
plt.ylabel('Percentage of similar record linkage tasks')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
plt.legend(title='Tests',fontsize='large')  # Add legend title
plt.show()
